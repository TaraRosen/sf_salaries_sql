# %%
# import libraries
import pandas as pd
import sqlite3

# %%
# connect to database
conn = sqlite3.connect('''database.sqlite''')

# create cursor object
cur = conn.cursor()

# %%
cur.execute('''SELECT * FROM Salaries;''')               # sql query
salaries_df = pd.DataFrame(cur.fetchall())               # create dataframe from sql query
salaries_df.columns = [x[0] for x in cur.description]    # labels dataframe columns
salaries_df                                              # view dataframe
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY        167411
# 1                      CAPTAIN III (POLICE DEPARTMENT)        155966
# 2                      CAPTAIN III (POLICE DEPARTMENT)        212739
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)        134402
# ...                                                ...           ...
# ...

# %%
# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM Salaries;'):
    print(row)

# %%
salaries_df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
salaries_df['OvertimePay'].value_counts()

# %%
cur.execute('''SELECT EmployeeName, BasePay, OvertimePay 
                FROM Salaries;''')
pay_df = pd.DataFrame(cur.fetchall())
pay_df.columns = [x[0] for x in cur.description]
pay_df
# Out:
#              EmployeeName       BasePay   OvertimePay
# 0          NATHANIEL FORD        167411             0
# 1            GARY JIMENEZ        155966        245132
# 2          ALBERT PARDINI        212739        106088
# 3       CHRISTOPHER CHONG         77916       56120.7
# 4         PATRICK GARDNER        134402          9737
# ...                   ...           ...           ...
# 148649      Roy I Tillery             0             0
# 148650       Not provided  Not Provided  Not Provided
# 148651       Not provided  Not Provided  Not Provided
# 148652       Not provided  Not Provided  Not Provided
# 148653          Joe Lopez             0             0
#
# [148654 rows x 3 columns]

# %%
cur.execute('''SELECT EmployeeName, BasePay
               FROm Salaries
               WHERE BasePay >= 300000;''')
over_500_base_df = pd.DataFrame(cur.fetchall())
over_500_base_df.columns = [x[0] for x in cur.description]
over_500_base_df
# Out:
#              EmployeeName       BasePay
# 0            Gregory Suhr        302578
# 1          Gregory P Suhr        319275
# 2    Joanne M Hayes-White        313686
# 3           Robert L Shaw        315572
# 4       Harlan L Kelly-Jr        313313
# ..                    ...           ...
# 616     Harlan L Kelly-Jr        310161
# 617          Not provided  Not Provided
# 618          Not provided  Not Provided
# 619          Not provided  Not Provided
# 620          Not provided  Not Provided
#
# [621 rows x 2 columns]

# %%
cur.execute('''SELECT JobTitle, TotalPay
               FROM Salaries
               ;''')
total_pay_df = pd.DataFrame(cur.fetchall())
total_pay_df.columns = [x[0] for x in cur.description]
total_pay_df
# Out:
#                                               JobTitle   TotalPay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)  538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)  335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  326373.19
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided       0.00
# 148651                                    Not provided       0.00
# 148652                                    Not provided       0.00
# 148653                      Counselor, Log Cabin Ranch    -618.13
#
# [148654 rows x 2 columns]

# %%
cur.execute('''SELECT * 
               FROM Salaries
               WHERE Year = 2014;''')                    # sql query
year_2014_df = pd.DataFrame(cur.fetchall())               # create dataframe from sql query
year_2014_df.columns = [x[0] for x in cur.description]    # labels dataframe columns
year_2014_df                                              # view dataframe
# Out:
#            Id          EmployeeName                    JobTitle       BasePay  \
# 0      110532           David Shinn              Deputy Chief 3        129150
# 1      110533            Amy P Hart           Asst Med Examiner        318835
# 2      110534  William J Coaker Jr.    Chief Investment Officer        257340
# 3      110535        Gregory P Suhr             Chief of Police        307450
# 4      110536  Joanne M Hayes-White      Chief, Fire Department        302068
# ...       ...                   ...                         ...           ...
# 38118  148650         Roy I Tillery                   Custodian             0
# 38119  148651          Not provided                Not provided  Not Provided
# 38120  148652          Not provided                Not provided  Not Provided
# 38121  148653          Not provided                Not provided  Not Provided
# 38122  148654             Joe Lopez  Counselor, Log Cabin Ranch             0
#
# ...

# %%
year_2014 = salaries_df[salaries_df.Year == 2014]

# %%
year_2014

# %%
# write the new dataframe to a new SQLite table
year_2014_df.to_sql('year_2014', con=conn, if_exists="replace")

# %%
year_2014_df
# Out:
#            Id          EmployeeName                    JobTitle       BasePay  \
# 0      110532           David Shinn              Deputy Chief 3        129150
# 1      110533            Amy P Hart           Asst Med Examiner        318835
# 2      110534  William J Coaker Jr.    Chief Investment Officer        257340
# 3      110535        Gregory P Suhr             Chief of Police        307450
# 4      110536  Joanne M Hayes-White      Chief, Fire Department        302068
# ...       ...                   ...                         ...           ...
# 38118  148650         Roy I Tillery                   Custodian             0
# 38119  148651          Not provided                Not provided  Not Provided
# 38120  148652          Not provided                Not provided  Not Provided
# 38121  148653          Not provided                Not provided  Not Provided
# 38122  148654             Joe Lopez  Counselor, Log Cabin Ranch             0
#
# ...

# %%
# write the new dataframe to a new SQLite table
year_2014_df.to_sql('year_2014', conn, if_exists="replace")

# %%
# close the connection
conn.close()

# %%
# connect to database
conn = sqlite3.connect('''year_2014.sqlite''')

# create cursor object
cur = conn.cursor()

# %%
cur.execute('''SELECT * 
                FROM year_2014;''')
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#         index      Id          EmployeeName                    JobTitle  \
# 0      110531  110532           David Shinn              Deputy Chief 3
# 1      110532  110533            Amy P Hart           Asst Med Examiner
# 2      110533  110534  William J Coaker Jr.    Chief Investment Officer
# 3      110534  110535        Gregory P Suhr             Chief of Police
# 4      110535  110536  Joanne M Hayes-White      Chief, Fire Department
# ...       ...     ...                   ...                         ...
# 38118  148649  148650         Roy I Tillery                   Custodian
# 38119  148650  148651          Not provided                Not provided
# 38120  148651  148652          Not provided                Not provided
# 38121  148652  148653          Not provided                Not provided
# 38122  148653  148654             Joe Lopez  Counselor, Log Cabin Ranch
#
#             BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...
